# %%
import numpy as np

true_w = np.array([3])
inp = []
output = []
d = len(true_w)
points = []

for i in range(10000):
    x = np.random.randn(d)
    y = true_w.dot(x)+np.random.randn()
    points.append((x,y))
    inp.append(x)
    output.append(y)

def F(w):
    value = 0
    for x,y in points:
        value = value + (x.dot(w)-y)**2
    return value/len(points)


def dF(w):
    value = 0
    for x,y in points:
        value = value + 2*(x.dot(w)-y)*x
    return value/len(points)


def gradientD():
    w = np.zeros(1)
    l = 0.01
    for i in range(50):
        f = F(w)
        g = dF(w)
        w = w - l * g
        print("iteration : {}, w : {}, f : {}, g :{}".format(i,w,f,g))
gradientD()
# Out:
# iteration : 0, w : [0.06045526], f : 10.058227607765277, g :[-6.04552607]
# iteration : 1, w : [0.11968987], f : 9.696433492125099, g :[-5.92346097]
# iteration : 2, w : [0.17772848], f : 9.349101837596104, g :[-5.80386048]
# iteration : 3, w : [0.23459522], f : 9.015654517635301, g :[-5.68667485]
# iteration : 4, w : [0.29031378], f : 8.695536515894785, g :[-5.57185531]
# iteration : 5, w : [0.34490732], f : 8.388215002408288, g :[-5.45935409]
# iteration : 6, w : [0.39839856], f : 8.093178446706721, g :[-5.34912438]
# iteration : 7, w : [0.45080976], f : 7.809935766385637, g :[-5.24112031]
# iteration : 8, w : [0.50216273], f : 7.538015509708526, g :[-5.13529696]
# iteration : 9, w : [0.55247884], f : 7.276965070885135, g :[-5.03161028]
# iteration : 10, w : [0.60177901], f : 7.026349936718063, g :[-4.93001713]
# iteration : 11, w : [0.65008376], f : 6.785752963364292, g :[-4.83047525]
# iteration : 12, w : [0.69741319], f : 6.554773682007684, g :[-4.73294322]
# iteration : 13, w : [0.743787], f : 6.333027632286752, g :[-4.63738046]
# iteration : 14, w : [0.78922447], f : 6.1201457223680995, g :[-4.5437472]
# iteration : 15, w : [0.83374451], f : 5.915773614600415, g :[-4.45200449]
# iteration : 16, w : [0.87736566], f : 5.719571135726746, g :[-4.36211415]
# iteration : 17, w : [0.92010604], f : 5.531211710672884, g :[-4.27403879]
# iteration : 18, w : [0.96198346], f : 5.350381818969633, g :[-4.18774176]
# iteration : 19, w : [1.00301533], f : 5.176780472904529, g :[-4.10318715]
# iteration : 20, w : [1.04321873], f : 5.010118716533666, g :[-4.02033978]
# iteration : 21, w : [1.08261038], f : 4.850119144720408, g :[-3.93916518]
# iteration : 22, w : [1.12120668], f : 4.69651544140012, g :[-3.85962957]
# iteration : 23, w : [1.15902368], f : 4.549051936302476, g :[-3.78169986]
# iteration : 24, w : [1.19607711], f : 4.407483179393421, g :[-3.70534364]
# iteration : 25, w : [1.2323824], f : 4.271573532328492, g :[-3.63052912]
# iteration : 26, w : [1.26795466], f : 4.1410967762376005, g :[-3.55722517]
# iteration : 27, w : [1.30280867], f : 4.015835735188257, g :[-3.48540131]
# iteration : 28, w : [1.33695895], f : 3.8955819147005895, g :[-3.41502764]
# iteration : 29, w : [1.37041969], f : 3.780135154712559, g :[-3.34607488]
# iteration : 30, w : [1.40320484], f : 3.669303296417422, g :[-3.27851435]
# iteration : 31, w : [1.43532802], f : 3.5629018624193782, g :[-3.21231793]
# iteration : 32, w : [1.4668026], f : 3.4607537496746787, g :[-3.14745808]
# iteration : 33, w : [1.49764168], f : 3.362688934707068, g :[-3.08390782]
# iteration : 34, w : [1.52785808], f : 3.2685441906072197, g :[-3.0216407]
# iteration : 35, w : [1.55746439], f : 3.1781628153448374, g :[-2.96063081]
# iteration : 36, w : [1.58647292], f : 3.0913943709412237, g :[-2.90085277]
# iteration : 37, w : [1.61489574], f : 3.0080944330682966, g :[-2.84228171]
# iteration : 38, w : [1.64274467], f : 2.928124350657331, g :[-2.78489326]
# iteration : 39, w : [1.6700313], f : 2.8513510151168577, g :[-2.72866353]
# iteration : 40, w : [1.696767], f : 2.777646638776189, g :[-2.67356914]
# iteration : 41, w : [1.72296287], f : 2.7068885421854576, g :[-2.61958716]
# iteration : 42, w : [1.74862982], f : 2.6389589499180865, g :[-2.56669512]
# iteration : 43, w : [1.77377853], f : 2.573744794535946, g :[-2.51487103]
# iteration : 44, w : [1.79841946], f : 2.5111375283909254, g :[-2.46409332]
# iteration : 45, w : [1.82256287], f : 2.4510329429495767, g :[-2.41434086]
# iteration : 46, w : [1.8462188], f : 2.393330995339991, g :[-2.36559295]
# iteration : 47, w : [1.86939709], f : 2.3379356418326167, g :[-2.31782931]
# iteration : 48, w : [1.89210739], f : 2.2847546779772956, g :[-2.27103007]
# iteration : 49, w : [1.91435915], f : 2.233699585130832, g :[-2.22517574]
